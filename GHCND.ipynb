# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
f='~/github/datasets/598354.csv'
data=pd.read_csv(f)

# %%
data.head()
# Out:
#              STATION                   STATION_NAME      DATE  MDPR  DAPR  \
# 0  GHCND:USR0000CTHO  THOMES CREEK CALIFORNIA CA US  20140101 -9999 -9999
# 1  GHCND:USR0000CTHO  THOMES CREEK CALIFORNIA CA US  20140102 -9999 -9999
# 2  GHCND:USR0000CTHO  THOMES CREEK CALIFORNIA CA US  20140103 -9999 -9999
# 3  GHCND:USR0000CTHO  THOMES CREEK CALIFORNIA CA US  20140104 -9999 -9999
# 4  GHCND:USR0000CTHO  THOMES CREEK CALIFORNIA CA US  20140105 -9999 -9999
#
#    PRCP  TMAX  TMIN  TOBS
# 0 -9999   217    83 -9999
# 1 -9999   217    72 -9999
# 2 -9999   206    78 -9999
# 3 -9999   206    94 -9999
# 4 -9999   206   100 -9999

# %%
data2= data[(data.TMIN > -9999)]
data3= data2[(data2.DATE>=20150601) & (data2.DATE>=20150601) & (data2.PRCP>0)]

# %%
data3
# Out:
#                   STATION                 STATION_NAME      DATE  MDPR  DAPR  \
# 1156    GHCND:USC00049099       TWENTYNINE PALMS CA US  20150701 -9999 -9999
# 1173    GHCND:USC00049099       TWENTYNINE PALMS CA US  20150718 -9999 -9999
# 1174    GHCND:USC00049099       TWENTYNINE PALMS CA US  20150719 -9999 -9999
# 1185    GHCND:USC00049099       TWENTYNINE PALMS CA US  20150730 -9999 -9999
# 2944    GHCND:USC00047902          SANTA BARBARA CA US  20150609 -9999 -9999
# 2945    GHCND:USC00047902          SANTA BARBARA CA US  20150610 -9999 -9999
# 2946    GHCND:USC00047902          SANTA BARBARA CA US  20150611 -9999 -9999
# 2983    GHCND:USC00047902          SANTA BARBARA CA US  20150718 -9999 -9999
# 2984    GHCND:USC00047902          SANTA BARBARA CA US  20150719 -9999 -9999
# 2985    GHCND:USC00047902          SANTA BARBARA CA US  20150720 -9999 -9999
# 3537    GHCND:USC00042214            CULVER CITY CA US  20150609 -9999 -9999
# 3541    GHCND:USC00042214            CULVER CITY CA US  20150613 -9999 -9999
# 3575    GHCND:USC00042214            CULVER CITY CA US  20150718 -9999 -9999
# 3576    GHCND:USC00042214            CULVER CITY CA US  20150719 -9999 -9999
# 3577    GHCND:USC00042214            CULVER CITY CA US  20150720 -9999 -9999
# 5342    GHCND:USC00045968  MOUNT LAGUNA NUMBER 3 CA US  20150609 -9999 -9999
# 5363    GHCND:USC00045968  MOUNT LAGUNA NUMBER 3 CA US  20150630 -9999 -9999
# 5364    GHCND:USC00045968  MOUNT LAGUNA NUMBER 3 CA US  20150701 -9999 -9999
# 5365    GHCND:USC00045968  MOUNT LAGUNA NUMBER 3 CA US  20150702 -9999 -9999
# 5381    GHCND:USC00045968  MOUNT LAGUNA NUMBER 3 CA US  20150718 -9999 -9999
# 5382    GHCND:USC00045968  MOUNT LAGUNA NUMBER 3 CA US  20150719 -9999 -9999
# 5383    GHCND:USC00045968  MOUNT LAGUNA NUMBER 3 CA US  20150720 -9999 -9999
# 5393    GHCND:USC00045968  MOUNT LAGUNA NUMBER 3 CA US  20150730 -9999 -9999
# 5394    GHCND:USC00045968  MOUNT LAGUNA NUMBER 3 CA US  20150731 -9999 -9999
# 5419    GHCND:USC00045968  MOUNT LAGUNA NUMBER 3 CA US  20150825 -9999 -9999
# 5420    GHCND:USC00045968  MOUNT LAGUNA NUMBER 3 CA US  20150826 -9999 -9999
# 5421    GHCND:USC00045968  MOUNT LAGUNA NUMBER 3 CA US  20150827 -9999 -9999
# 9886    GHCND:USC00044405            JOSHUA TREE CA US  20150610 -9999 -9999
# 9907    GHCND:USC00044405            JOSHUA TREE CA US  20150701 -9999 -9999
# 9908    GHCND:USC00044405            JOSHUA TREE CA US  20150702 -9999 -9999
# ...                   ...                          ...       ...   ...   ...
# 639239  GHCND:USC00047326          REDONDO BEACH CA US  20150701 -9999 -9999
# 639256  GHCND:USC00047326          REDONDO BEACH CA US  20150718 -9999 -9999
# 639257  GHCND:USC00047326          REDONDO BEACH CA US  20150719 -9999 -9999
# 639258  GHCND:USC00047326          REDONDO BEACH CA US  20150720 -9999 -9999
# 639259  GHCND:USC00047326          REDONDO BEACH CA US  20150721 -9999 -9999
# 639260  GHCND:USC00047326          REDONDO BEACH CA US  20150722 -9999 -9999
# 640926  GHCND:USC00049742                WINTERS CA US  20150610 -9999 -9999
# 645095  GHCND:USC00047339           REDWOOD CITY CA US  20150610 -9999 -9999
# 647258  GHCND:USC00040943                  BODIE CA US  20150605 -9999 -9999
# 647259  GHCND:USC00040943                  BODIE CA US  20150606 -9999 -9999
# 647260  GHCND:USC00040943                  BODIE CA US  20150607 -9999 -9999
# 647264  GHCND:USC00040943                  BODIE CA US  20150611 -9999 -9999
# 647281  GHCND:USC00040943                  BODIE CA US  20150628 -9999 -9999
# 647285  GHCND:USC00040943                  BODIE CA US  20150702 -9999 -9999
# 647288  GHCND:USC00040943                  BODIE CA US  20150705 -9999 -9999
# 647289  GHCND:USC00040943                  BODIE CA US  20150706 -9999 -9999
# 647290  GHCND:USC00040943                  BODIE CA US  20150707 -9999 -9999
# 647291  GHCND:USC00040943                  BODIE CA US  20150708 -9999 -9999
# 647292  GHCND:USC00040943                  BODIE CA US  20150709 -9999 -9999
# 647294  GHCND:USC00040943                  BODIE CA US  20150711 -9999 -9999
# 647295  GHCND:USC00040943                  BODIE CA US  20150712 -9999 -9999
# 647301  GHCND:USC00040943                  BODIE CA US  20150718 -9999 -9999
# 647316  GHCND:USC00040943                  BODIE CA US  20150802 -9999 -9999
# 647321  GHCND:USC00040943                  BODIE CA US  20150808 -9999 -9999
# 649119  GHCND:USC00046006       MOUNT WILSON CBS CA US  20150609 -9999 -9999
# 649140  GHCND:USC00046006       MOUNT WILSON CBS CA US  20150630 -9999 -9999
# 649158  GHCND:USC00046006       MOUNT WILSON CBS CA US  20150718 -9999 -9999
# 649159  GHCND:USC00046006       MOUNT WILSON CBS CA US  20150719 -9999 -9999
# 649160  GHCND:USC00046006       MOUNT WILSON CBS CA US  20150720 -9999 -9999
# 649170  GHCND:USC00046006       MOUNT WILSON CBS CA US  20150730 -9999 -9999
#
#         PRCP  TMAX  TMIN  TOBS
# 1156      51   394   250   322
# 1173      51   389   228   239
# 1174      41   322   206   311
# 1185      66   378   244   333
# 2944     155   228   144   194
# 2945      20   211   161   200
# 2946       3   206   133   194
# 2983       5   244   144   239
# 2984       3   283   144   272
# 2985       3   283   206   256
# 3537       3   300   161   261
# 3541       8   217   172   211
# 3575      38   317   178   194
# 3576      71   317   194   300
# 3577      13   306   233   267
# 5342       3   256   150   161
# 5363       8   283   161   217
# 5364       3   267   161   206
# 5365       8   272   144   256
# 5381      15   272   156   194
# 5382      64   211   122   167
# 5383       8   211   111   194
# 5393     381   250   144   178
# 5394       8   261   128   239
# 5419       5   244   183   222
# 5420      36   261   150   183
# 5421      13   261   144   261
# 9886       5   311   161   222
# 9907      25   383   233   233
# 9908      33   317   222   261
# ...      ...   ...   ...   ...
# 639239     3   233   178   211
# 639256    81   283   167   183
# 639257    36   294   183   239
# 639258    36   300   222   250
# 639259     5   256   200   244
# 639260     8   250   194   233
# 640926     3   328   194   217
# 645095    25   217   167   167
# 647258    61   106   -22    61
# 647259    43   133    -6    61
# 647260     8   150    11    94
# 647264    79   128    67   111
# 647281     3   278   139 -9999
# 647285   102   283   100   139
# 647288     5   183    11   167
# 647289    25   233    22   128
# 647290    36   233    22   156
# 647291    79   211    11 -9999
# 647292    18   189    17    61
# 647294    13   161    -6    94
# 647295     3   200     6 -9999
# 647301     5   244     6 -9999
# 647316   135   256    89   133
# 647321    20   161   -17    17
# 649119    30   250   139   144
# 649140     3   317   172   228
# 649158   165   200   122   167
# 649159   655   244   128   128
# 649160    71   239   128   150
# 649170    18   311   189   189
#
# [1937 rows x 9 columns]

# %%
stations = data2[(data2.STATION=='GHCND:USC00045968') | (data2.STATION=='GHCND:USC00047902') | (data2.STATION=='GHCND:USC00046006')]

# %%
st = stations.groupby(['STATION'])
temp = st.agg({'TMIN' : [np.min], 'TMAX' : [np.max]})
temp.plot(kind='bar')

# %%
june=stations[(stations.DATE>=20150601) & (stations.DATE<=20150630)]
rain=june.groupby(['STATION'])
rain.plot('DATE','PRCP')
# Out:
# STATION
# GHCND:USC00045968    Axes(0.125,0.125;0.775x0.775)
# GHCND:USC00046006    Axes(0.125,0.125;0.775x0.775)
# GHCND:USC00047902    Axes(0.125,0.125;0.775x0.775)
# dtype: object
